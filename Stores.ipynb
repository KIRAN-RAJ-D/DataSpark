# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
Stores = r"C:\Users\kiran\DataSpark_project2_files\Stores.csv"

# Try using a different encoding
df = pd.read_csv(Stores, encoding='latin1')
df
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
nan_value = df[df.isnull().any(axis=1)]
nan_value
# Out:
#     StoreKey Country   State  Square Meters Open Date
# 66         0  Online  Online            NaN  1/1/2010

# %%
df['Country'].isin(['Online']).any()
# Out:
# np.True_

# %%
(df['Country'] == 'Online').sum()
# Out:
# np.int64(1)

# %%
dst = df[df['Country'] != 'Online']

# %%
df['Open Date'] = pd.to_datetime(df['Open Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  67 non-null     object
#  4   Open Date      67 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df = df.rename(columns={"Square Meters": "Square_Meters", "Open Date": "Open_Date"})

# %%
df
# Out:
#     StoreKey        Country                         State Square_Meters  \
# 0          1      Australia  Australian Capital Territory         595.0
# 1          2      Australia            Northern Territory         665.0
# 2          3      Australia               South Australia        2000.0
# 3          4      Australia                      Tasmania        2000.0
# 4          5      Australia                      Victoria        2000.0
# ..       ...            ...                           ...           ...
# 62        63  United States                          Utah        2000.0
# 63        64  United States                 Washington DC        1330.0
# 64        65  United States                 West Virginia        1785.0
# 65        66  United States                       Wyoming         840.0
# 66         0         Online                        Online             -
#
#     Open_Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09
# ...

# %%
df = df.rename(columns={"StoreKey":"Store_Key"})
df
# Out:
#     Store_Key        Country                         State Square_Meters  \
# 0           1      Australia  Australian Capital Territory         595.0
# 1           2      Australia            Northern Territory         665.0
# 2           3      Australia               South Australia        2000.0
# 3           4      Australia                      Tasmania        2000.0
# 4           5      Australia                      Victoria        2000.0
# ..        ...            ...                           ...           ...
# 62         63  United States                          Utah        2000.0
# 63         64  United States                 Washington DC        1330.0
# 64         65  United States                 West Virginia        1785.0
# 65         66  United States                       Wyoming         840.0
# 66          0         Online                        Online             -
#
#     Open_Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
df=pd.DataFrame(df)
df.to_csv("Stores.csv")
